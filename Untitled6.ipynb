# %%
import pickle
import sys
sys.path.append('/Users/ak/Yandex.Disk.localized/sentiment-neural_past_from_Denis_Kirjanov/src')

# %%
with open('model_tokenize.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model.vocab_size
# Out:
# 50000

# %%
with open('data_tokenized.pkl', 'rb') as f:
    X_idx = pickle.load(f)

# %%
import numpy as np

# %%
all_idx = []
for x in X_idx:
    all_idx.extend(x)

# %%
un = np.unique(all_idx)
np.min(un)
# Out:
# 0

# %%
model.reverse_dictionary
# Out:
# {0: 'UNK',
#  1: 'не',
#  2: 'быть',
#  3: 'все',
#  4: 'карта',
#  5: 'сбербанк',
#  6: 'но',
#  7: 'для',
#  8: 'день',
#  9: 'год',
#  10: 'отделение',
#  11: 'банк',
#  12: 'такой',
#  13: 'деньги',
#  14: 'свой',
#  15: 'очень',
#  16: 'еще',
#  17: 'только',
#  18: 'сотрудник',
#  19: 'сказать',
#  20: 'магазин',
#  21: 'нет',
#  22: 'уже',
#  23: 'получать',
#  24: 'если',
#  25: 'клиент',
#  26: 'через',
#  27: 'работать',
#  28: 'время',
#  29: 'очередь',
#  30: 'приходить',
#  31: 'банка',
#  32: 'мочь',
#  33: 'другой',
#  34: 'работа',
#  35: 'вопрос',
#  36: 'документ',
#  37: 'услуга',
#  38: 'можно',
#  39: 'человек',
#  40: 'заявление',
#  41: 'счет',
#  42: 'бы',
#  43: 'после',
#  44: 'без',
#  45: 'просто',
#  46: 'обращаться',
#  47: 'данный',
#  48: 'кредит',
#  49: 'ни',
#  50: 'рубль',
#  51: 'мфц',
#  52: 'офис',
#  53: 'банкомат',
#  54: 'девушка',
#  55: 'хотеть',
#  56: 'консультант',
#  57: 'сумма',
#  58: 'компания',
#  59: 'говорить',
#  60: 'сделать',
#  61: 'телефон',
#  62: 'новый',
#  63: 'обслуживание',
#  64: 'даже',
#  65: 'решать',
#  66: 'знать',
#  67: 'самый',
#  68: 'срок',
#  69: 'месяц',
#  70: 'ответ',
#  71: 'принимать',
#  72: 'минута',
#  73: 'номер',
#  74: 'оформлять',
#  75: 'ждать',
#  76: 'проблема',
#  77: 'нужно',
#  78: 'средство',
#  79: 'хороший',
#  80: 'россия',
#  81: 'может',
#  82: 'сегодня',
#  83: 'отвечать',
#  84: 'себя',
#  85: 'первый',
#  86: 'больше',
#  87: 'давать',
#  88: 'центр',
#  89: 'становиться',
#  90: 'товар',
#  91: 'информация',
#  92: 'сайт',
#  93: 'всегда',
#  94: 'написать',
#  95: 'помогать',
#  96: 'проходить',
#  97: 'вообще',
#  98: 'ничего',
#  99: 'стоять',
#  100: 'делать',
#  101: 'почему',
#  102: 'да',
#  103: 'обращение',
#  104: 'час',
#  105: 'специалист',
#  106: 'место',
#  107: 'должный',
#  108: 'приходиться',
#  109: 'более',
#  110: 'электронный',
#  111: 'спасибо',
#  112: 'оператор',
#  113: 'итог',
#  114: 'дело',
#  115: 'цена',
#  116: 'начинать',
#  117: 'оказываться',
#  118: 'госуслуга',
#  119: 'позвонить',
#  120: 'нужный',
#  121: 'также',
#  122: 'интернет',
#  123: 'касса',
#  124: 'выдавать',
#  125: 'купить',
#  126: 'теперь',
#  127: 'хорошо',
#  128: 'ситуация',
#  129: 'понимать',
#  130: 'находить',
#  131: 'взять',
#  132: 'предлагать',
#  133: 'случай',
#  134: 'идти',
#  135: 'подходить',
#  136: 'кредитный',
#  137: 'страховой',
#  138: 'быстро',
#  139: 'договор',
#  140: 'неделя',
#  141: 'хотя',
#  142: 'покупка',
#  143: 'оплачивать',
#  144: 'смс',
#  145: 'сообщать',
#  146: 'много',
#  147: 'никто',
#  148: 'платеж',
#  149: 'страховка',
#  150: 'сразу',
#  151: 'весь',
#  152: 'потом',
#  153: 'звонить',
#  154: 'сервис',
#  155: 'скидка',
#  156: 'отзыв',
#  157: 'руб',
#  158: 'сейчас',
#  159: 'государственный',
#  160: 'город',
#  161: 'лицо',
#  162: 'паспорт',
#  163: 'выбирать',
#  164: 'гражданин',
#  165: 'иметь',
#  166: 'общий',
#  167: 'получение',
#  168: 'большой',
#  169: 'отношение',
#  170: 'система',
#  171: 'спрашивать',
#  172: 'акция',
#  173: 'продавец',
#  174: 'никакой',
#  175: 'оставаться',
#  176: 'ребенок',
#  177: 'несколько',
#  178: 'здесь',
#  179: 'приезжать',
#  180: 'подавать',
#  181: 'сеть',
#  182: 'объяснять',
#  183: 'пойти',
#  184: 'думать',
#  185: 'пока',
#  186: 'уходить',
#  187: 'писать',
#  188: 'вид',
#  189: 'узнавать',
#  190: 'оплата',
#  191: 'москва',
#  192: 'менеджер',
#  193: 'просить',
#  194: 'следующий',
#  195: 'персонал',
#  196: 'филиал',
#  197: 'портал',
#  198: 'течение',
#  199: 'слово',
#  200: 'именно',
#  201: 'операция',
#  202: 'конечно',
#  203: 'заявка',
#  204: 'связь',
#  205: 'решение',
#  206: 'билайн',
#  207: 'снимать',
#  208: 'адрес',
#  209: 'друг',
#  210: 'всего',
#  211: 'денежный',
#  212: 'отправлять',
#  213: 'помощь',
#  214: 'пользоваться',
#  215: 'находиться',
#  216: 'зайти',
#  217: 'право',
#  218: 'вернуть',
#  219: 'брать',
#  220: 'предоставлять',
#  221: 'являться',
#  222: 'рабочий',
#  223: 'смочь',
#  224: 'окно',
#  225: 'возможность',
#  226: 'момент',
#  227: 'полис',
#  228: 'страхование',
#  229: 'регистрация',
#  230: 'рассказывать',
#  231: 'любой',
#  232: 'онлайн',
#  233: 'личный',
#  234: 'мало',
#  235: 'ходить',
#  236: 'осаго',
#  237: 'рф',
#  238: 'выплата',
#  239: 'последний',
#  240: 'закон',
#  241: 'открывать',
#  242: 'полный',
#  243: 'сбер',
#  244: 'опять',
#  245: 'добрый',
#  246: 'область',
#  247: 'претензия',
#  248: 'линия',
#  249: 'машина',
#  250: 'оставлять',
#  251: 'сидеть',
#  252: 'видеть',
#  253: 'попросить',
#  254: 'покупать',
#  255: 'справка',
#  256: 'указывать',
#  257: 'отдел',
#  258: 'проводить',
#  259: 'происходить',
#  260: 'рассмотрение',
#  261: 'отказываться',
#  262: 'условие',
#  263: 'подарок',
#  264: 'конец',
#  265: 'составлять',
#  266: 'оформление',
#  267: 'терминал',
#  268: 'служба',
#  269: 'звонок',
#  270: 'жизнь',
#  271: 'проверять',
#  272: 'мобильный',
#  273: 'программа',
#  274: 'туда',
#  275: 'пенсионный',
#  276: 'закрывать',
#  277: 'качество',
#  278: 'потому',
#  279: 'смотреть',
#  280: 'выходить',
#  281: 'необходимо',
#  282: 'район',
#  283: 'перевод',
#  284: 'снова',
#  285: 'поэтому',
#  286: 'российский',
#  287: 'разбираться',
#  288: 'ипотека',
#  289: 'сентябрь',
#  290: 'внимание',
#  291: 'хотеться',
#  292: 'кабинет',
#  293: 'долго',
#  294: 'забирать',
#  295: 'выбор',
#  296: 'выдача',
#  297: 'горячий',
#  298: 'проект',
#  299: 'результат',
#  300: 'рука',
#  301: 'готовый',
#  302: 'организация',
#  303: 'сторона',
#  304: 'сотрудница',
#  305: 'вклад',
#  306: 'прием',
#  307: 'никогда',
#  308: 'руководитель',
#  309: 'данные',
#  310: 'пытаться',
#  311: 'чек',
#  312: 'талон',
#  313: 'действие',
#  314: 'эльдорадо',
#  315: 'процент',
#  316: 'размер',
#  317: 'ул',
#  318: 'история',
#  319: 'тогда',
#  320: 'покупатель',
#  321: 'причина',
#  322: 'летуаль',
#  323: 'платить',
#  324: 'посмотреть',
#  325: 'работник',
#  326: 'недвижимость',
#  327: 'огромный',
#  328: 'ставка',
#  329: 'вносить',
#  330: 'попадать',
#  331: 'порядок',
#  332: 'фонд',
#  333: 'отказ',
#  334: 'пенсия',
#  335: 'ужасный',
#  336: 'видимо',
#  337: 'почти',
#  338: 'единый',
#  339: 'назад',
#  340: 'стоимость',
#  341: 'обслуживать',
#  342: 'получаться',
#  343: 'дополнительный',
#  344: 'пора',
#  345: 'кассир',
#  346: 'банковский',
#  347: 'вежливый',
#  348: 'муж',
#  349: 'ремонт',
#  350: 'утро',
#  351: 'октябрь',
#  352: 'ведь',
#  353: 'приятный',
#  354: 'число',
#  355: 'считать',
#  356: 'правый',
#  357: 'зал',
#  358: 'бизнес',
#  359: 'квартира',
#  360: 'суд',
#  361: 'ошибка',
#  362: 'рано',
#  363: 'предоставление',
#  364: 'сколько',
#  365: 'народ',
#  366: 'таки',
#  367: 'штраф',
#  368: 'дома',
#  369: 'возврат',
#  370: 'часть',
#  371: 'переводить',
#  372: 'заказ',
#  373: 'наличие',
#  374: 'отличный',
#  375: 'поддержка',
#  376: 'показывать',
#  377: 'заказывать',
#  378: 'искать',
#  379: 'нельзя',
#  380: 'появляться',
#  381: 'далеко',
#  382: 'просьба',
#  383: 'выписка',
#  384: 'учет',
#  385: 'разный',
#  386: 'поступать',
#  387: 'ехать',
#  388: 'ожидание',
#  389: 'хоть',
#  390: 'отказывать',
#  391: 'довольный',
#  392: 'кроме',
#  393: 'необходимый',
#  394: 'сообщение',
#  395: 'комиссия',
#  396: 'жалоба',
#  397: 'заходить',
#  398: 'косметика',
#  399: 'занимать',
#  400: 'запись',
#  401: 'уточнять',
#  402: 'совсем',
#  403: 'дозваниваться',
#  404: 'постоянно',
#  405: 'руководство',
#  406: 'продажа',
#  407: 'бесплатный',
#  408: 'приятно',
#  409: 'пара',
#  410: 'продукт',
#  411: 'подключать',
#  412: 'увидеть',
#  413: 'возникать',
#  414: 'сюда',
#  415: 'вход',
#  416: 'начинаться',
#  417: 'причем',
#  418: 'удобно',
#  419: 'отмечать',
#  420: 'сертификат',
#  421: 'часто',
#  422: 'рядом',
#  423: 'рассматривать',
#  424: 'представлять',
#  425: 'девочка',
#  426: 'приобретать',
#  427: 'дом',
#  428: 'точно',
#  429: 'вечер',
#  430: 'московский',
#  431: 'бывать',
#  432: 'однако',
#  433: 'росгосстрах',
#  434: 'отдавать',
#  435: 'дорогой',
#  436: 'плохо',
#  437: 'далее',
#  438: 'задолженность',
#  439: 'называть',
#  440: 'форма',
#  441: 'близкий',
#  442: 'прийти',
#  443: 'заполнять',
#  444: 'дата',
#  445: 'давно',
#  446: 'возможно',
#  447: 'нибудь',
#  448: 'автомобиль',
#  449: 'продавать',
#  450: 'объект',
#  451: 'охранник',
#  452: 'база',
#  453: 'поставлять',
#  454: 'надеяться',
#  455: 'заниматься',
#  456: 'потратить',
#  457: 'данна',
#  458: 'уралсиб',
#  459: 'заканчиваться',
#  460: 'орган',
#  461: 'участие',
#  462: 'страна',
#  463: 'старый',
#  464: 'технический',
#  465: 'управление',
#  466: 'уровень',
#  467: 'ипотечный',
#  468: 'любить',
#  469: 'бонус',
#  470: 'пфр',
#  471: 'плюс',
#  472: 'карточка',
#  473: 'рекомендовать',
#  474: 'понравиться',
#  475: 'вызывать',
#  476: 'социальный',
#  477: 'вчера',
#  478: 'жить',
#  479: 'направлять',
#  480: 'цель',
#  481: 'регион',
#  482: 'списывать',
#  483: 'ладно',
#  484: 'посещение',
#  485: 'предложение',
#  486: 'заявлять',
#  487: 'нравиться',
#  488: 'изменение',
#  489: 'сначала',
#  490: 'техника',
#  491: 'вроде',
#  492: 'впечатление',
#  493: 'правило',
#  494: 'потерять',
#  495: 'факт',
#  496: 'заблокировать',
#  497: 'тыс',
#  498: 'сей',
#  499: 'подтверждать',
#  500: 'федеральный',
#  501: 'житель',
#  502: 'семья',
#  503: 'уж',
#  504: 'тариф',
#  505: 'пакет',
#  506: 'стиль',
#  507: 'количество',
#  508: 'администратор',
#  509: 'очередной',
#  510: 'единственный',
#  511: 'оценка',
#  512: 'правда',
#  513: 'копия',
#  514: 'приносить',
#  515: 'представитель',
#  516: 'молодой',
#  517: 'письмо',
#  518: 'плохой',
#  519: 'доставка',
#  520: 'свое',
#  521: 'позволять',
#  522: 'отсутствие',
#  523: 'рынок',
#  524: 'воспользоваться',
#  525: 'зарегистрировать',
#  526: 'кадастровый',
#  527: 'успевать',
#  528: 'указанный',
#  529: 'глаз',
#  530: 'например',
#  531: 'использовать',
#  532: 'минус',
#  533: 'образ',
#  534: 'запрос',
#  535: 'капитал',
#  536: 'удобный',
#  537: 'отвратительный',
#  538: 'вводить',
#  539: 'советовать',
#  540: 'крупный',
#  541: 'лишь',
#  542: 'дебетовый',
#  543: 'новое',
#  544: 'зарплата',
#  545: 'женщина',
#  546: 'лично',
#  547: 'наконец',
#  548: 'обещать',
#  549: 'обращать',
#  550: 'фамилия',
#  551: 'невозможно',
#  552: 'сожаление',
#  553: 'скоро',
#  554: 'кстати',
#  555: 'высокий',
#  556: 'достаточно',
#  557: 'напоминать',
#  558: 'полагать',
#  559: 'желание',
#  560: 'август',
#  561: 'забывать',
#  562: 'сбой',
#  563: 'заплатить',
#  564: 'подписывать',
#  565: 'улица',
#  566: 'подобный',
#  567: 'допы',
#  568: 'посещать',
#  569: 'помещение',
#  570: 'маленький',
#  571: 'директор',
#  572: 'сила',
#  573: 'июль',
#  574: 'вымпелком',
#  575: 'поехать',
#  576: 'развитие',
#  577: 'вернуться',
#  578: 'поздно',
#  579: 'сведение',
#  580: 'уважаемый',
#  581: 'долг',
#  582: 'настроение',
#  583: 'официальный',
#  584: 'балл',
#  585: 'сдавать',
#  586: 'между',
#  587: 'крем',
#  588: 'ранее',
#  589: 'дверь',
#  590: 'ноябрь',
#  591: 'суббота',
#  592: 'вместо',
#  593: 'менять',
#  594: 'удивлять',
#  595: 'требовать',
#  596: 'связываться',
#  597: 'создавать',
#  598: 'пожалуйста',
#  599: 'дтп',
#  600: 'выходной',
#  601: 'аромат',
#  602: 'проверка',
#  603: 'ценник',
#  604: 'недостаток',
#  605: 'действительно',
#  606: 'выясняться',
#  607: 'особенно',
#  608: 'собираться',
#  609: 'погашение',
#  610: 'пункт',
#  611: 'родитель',
#  612: 'подсказывать',
#  613: 'замечать',
#  614: 'подача',
#  615: 'мера',
#  616: 'вода',
#  617: 'период',
#  618: 'здравствовать',
#  619: 'курс',
#  620: 'мама',
#  621: 'приложение',
#  622: 'требование',
#  623: 'сталкиваться',
#  624: 'повод',
#  625: 'домой',
#  626: 'основание',
#  627: 'активный',
#  628: 'передавать',
#  629: 'перезванивать',
#  630: 'врач',
#  631: 'консультация',
#  632: 'выполнять',
#  633: 'март',
#  634: 'тип',
#  635: 'материнский',
#  636: 'благодарность',
#  637: 'участок',
#  638: 'понятно',
#  639: 'июнь',
#  640: 'поменять',
#  641: 'рождение',
#  642: 'встречать',
#  643: 'сделка',
#  644: 'постоянный',
#  645: 'всякий',
#  646: 'подождать',
#  647: 'купюра',
#  648: 'входить',
#  649: 'реквизит',
#  650: 'млн',
#  651: 'любимый',
#  652: 'замена',
#  653: 'ожидать',
#  654: 'списание',
#  655: 'застраховывать',
#  656: 'приветливый',
#  657: 'доступ',
#  658: 'некоторые',
#  659: 'наличные',
#  660: 'ужас',
#  661: 'действовать',
#  662: 'равно',
#  663: 'график',
#  664: 'выяснять',
#  665: 'ассортимент',
#  666: 'росреестр',
#  667: 'новость',
#  668: 'совершенно',
#  669: 'мол',
#  670: 'тушь',
#  671: 'налог',
#  672: 'почта',
#  673: 'закрытие',
#  674: 'код',
#  675: 'пользователь',
#  676: 'спустя',
#  677: 'рамка',
#  678: 'финансовый',
#  679: 'менее',
#  680: 'муниципальный',
#  681: 'целое',
#  682: 'устанавливать',
#  683: 'территория',
#  684: 'продолжать',
#  685: 'операционист',
#  686: 'устраивать',
#  687: 'читать',
#  688: 'открытие',
#  689: 'выплачивать',
#  690: 'чуть',
#  691: 'абсолютно',
#  692: 'тренд',
#  693: 'совершать',
#  694: 'зачислять',
#  695: 'трубка',
#  696: 'план',
#  697: 'квитанция',
#  698: 'уведомление',
#  699: 'май',
#  700: 'прямой',
#  701: 'бесплатно',
#  702: 'вариант',
#  703: 'продлять',
#  704: 'январь',
#  705: 'мтс',
#  706: 'интересный',
#  707: 'апрель',
#  708: 'процедура',
#  709: 'куча',
#  710: 'естественно',
#  711: 'тестер',
#  712: 'состояние',
#  713: 'немного',
#  714: 'гибдд',
#  715: 'принцип',
#  716: 'нормально',
#  717: 'процесс',
#  718: 'простой',
#  719: 'модель',
#  720: 'завтра',
#  721: 'сутки',
#  722: 'относиться',
#  723: 'больший',
#  724: 'имущество',
#  725: 'примерно',
#  726: 'ставить',
#  727: 'разговор',
#  728: 'обычно',
#  729: 'пао',
#  730: 'высоко',
#  731: 'фото',
#  732: 'нога',
#  733: 'наверное',
#  734: 'значит',
#  735: 'остальной',
#  736: 'главное',
#  737: 'обязательно',
#  738: 'практически',
#  739: 'начало',
#  740: 'форум',
#  741: 'мнение',
#  742: 'отдельный',
#  743: 'желать',
#  744: 'обычный',
#  745: 'настоящий',
#  746: 'годовой',
#  747: 'перевыпуск',
#  748: 'оценивать',
#  749: 'милый',
#  750: 'способ',
#  751: 'недавно',
#  752: 'свидетельство',
#  753: 'посоветовать',
#  754: 'обед',
#  755: 'общение',
#  756: 'производить',
#  757: 'нормальный',
#  758: 'декабрь',
#  759: 'федерация',
#  760: 'группа',
#  761: 'вместе',
#  762: 'доступный',
#  763: 'глава',
#  764: 'международный',
#  765: 'обнаруживать',
#  766: 'небольшой',
#  767: 'достоинство',
#  768: 'защита',
#  769: 'мир',
#  770: 'авто',
#  771: 'дождаться',
#  772: 'быстрый',
#  773: 'знакомый',
#  774: 'налоговый',
#  775: 'возвращать',
#  776: 'режим',
#  777: 'общаться',
#  778: 'подумать',
#  779: 'парень',
#  780: 'страховать',
#  781: 'предыдущий',
#  782: 'располагать',
#  783: 'статус',
#  784: 'направление',
#  785: 'этаж',
#  786: 'реальный',
#  787: 'полностью',
#  788: 'совет',
#  789: 'городской',
#  790: 'использование',
#  791: 'столько',
#  792: 'список',
#  793: 'пол',
#  794: 'приглашать',
#  795: 'нерв',
#  796: 'технология',
#  797: 'главный',
#  798: 'детский',
#  799: 'вежливо',
#  800: 'положительный',
#  801: 'президент',
#  802: 'владелец',
#  803: 'попытка',
#  804: 'задавать',
#  805: 'снятие',
#  806: 'навязывать',
#  807: 'основной',
#  808: 'оказывать',
#  809: 'выражать',
#  810: 'помнить',
#  811: 'марка',
#  812: 'центральный',
#  813: 'слышать',
#  814: 'согласно',
#  815: 'пенсионер',
#  816: 'доход',
#  817: 'посетитель',
#  818: 'проведение',
#  819: 'будто',
#  820: 'иметься',
#  821: 'стойка',
#  822: 'соглашаться',
#  823: 'продукция',
#  824: 'довольно',
#  825: 'страховаться',
#  826: 'предупреждать',
#  827: 'удаваться',
#  828: 'вывод',
#  829: 'правительство',
#  830: 'собственность',
#  831: 'компьютер',
#  832: 'нарушение',
#  833: 'сочи',
#  834: 'ребята',
#  835: 'никак',
#  836: 'услышать',
#  837: 'многие',
#  838: 'кредитование',
#  839: 'якобы',
#  840: 'случаться',
#  841: 'понедельник',
#  842: 'собирать',
#  843: 'необходимость',
#  844: 'духи',
#  845: 'запускать',
#  846: 'заранее',
#  847: 'подробно',
#  848: 'опыт',
#  849: 'здание',
#  850: 'строительство',
#  851: 'малый',
#  852: 'обратно',
#  853: 'мужчина',
#  854: 'одобрять',
#  855: 'немой',
#  856: 'греф',
#  857: 'деятельность',
#  858: 'юридический',
#  859: 'талончик',
#  860: 'бумага',
#  861: 'участник',
#  862: 'судебный',
#  863: 'обязательный',
#  864: 'иной',
#  865: 'открытый',
#  866: 'везде',
#  867: 'складываться',
#  868: 'погасить',
#  869: 'дешево',
#  870: 'остаток',
#  871: 'лишний',
#  872: 'радовать',
#  873: 'чудо',
#  874: 'тратить',
#  875: 'иногда',
#  876: 'пароль',
#  877: 'поскольку',
#  878: 'подтверждение',
#  879: 'прямо',
#  880: 'перечислять',
#  881: 'осмотр',
#  882: 'выпускать',
#  883: 'крайне',
#  884: 'спокойно',
#  885: 'почитать',
#  886: 'снижать',
#  887: 'плата',
#  888: 'парфюм',
#  889: 'дорога',
#  890: 'пояснять',
#  891: 'обманывать',
#  892: 'заключать',
#  893: 'разговаривать',
#  894: 'набирать',
#  895: 'интересно',
#  896: 'собственный',
#  897: 'правильно',
#  898: 'платный',
#  899: 'заявитель',
#  900: 'зарплатный',
#  901: 'честно',
#  902: 'гарантия',
#  903: 'требоваться',
#  904: 'просрочка',
#  905: 'срочно',
#  906: 'каско',
#  907: 'лэтуаль',
#  908: 'кофе',
#  909: 'взгляд',
#  910: 'расчет',
#  911: 'этуаль',
#  912: 'вещь',
#  913: 'target',
#  914: 'внимательный',
#  915: 'компетентный',
#  916: 'коллега',
#  917: 'валюта',
#  918: 'смена',
#  919: 'ездить',
#  920: 'шок',
#  921: 'многофункциональный',
#  922: 'бланк',
#  923: 'физический',
#  924: 'минимум',
#  925: 'край',
#  926: 'петербург',
#  927: 'свободный',
#  928: 'сб',
#  929: 'подпись',
#  930: 'прикол',
#  931: 'соответствие',
#  932: 'пацан',
#  933: 'взнос',
#  934: 'соответственно',
#  935: 'население',
#  936: 'безопасность',
#  937: 'пятница',
#  938: 'платежный',
#  939: 'предусматривать',
#  940: 'рост',
#  941: 'привозить',
#  942: 'пробник',
#  943: 'холодильник',
#  944: 'благодаря',
#  945: 'включать',
#  946: 'голова',
#  947: 'статья',
#  948: 'управлять',
#  949: 'изменяться',
#  950: 'хватать',
#  951: 'реестр',
#  952: 'стол',
#  953: 'зато',
#  954: 'индивидуальный',
#  955: 'определенный',
#  956: 'дальнейший',
#  957: 'скорость',
#  958: 'осуществлять',
#  959: 'половина',
#  960: 'присылать',
#  961: 'реально',
#  962: 'низкий',
#  963: 'выход',
#  964: 'исполнительный',
#  965: 'потребитель',
#  966: 'молодец',
#  967: 'записываться',
#  968: 'доходить',
#  969: 'переходить',
#  970: 'возможный',
#  971: 'добавлять',
#  972: 'средний',
#  973: 'сильно',
#  974: 'начальник',
#  975: 'книга',
#  976: 'учитывать',
#  977: 'администрация',
#  978: 'голосование',
#  979: 'обман',
#  980: 'поиск',
#  981: 'оперативно',
#  982: 'объем',
#  983: 'жаль',
#  984: 'везти',
#  985: 'важный',
#  986: 'помада',
#  987: 'долгий',
#  988: 'жилье',
#  989: 'ока',
#  990: 'заставлять',
#  991: 'посылать',
#  992: 'внесение',
#  993: 'окошко',
#  994: 'республика',
#  995: 'бегать',
#  996: 'следовать',
#  997: 'власть',
#  998: 'бренд',
#  999: 'бумажка',
#  ...}
